# %%
print('Hello Vy, you AI journey has begun')

# %%
print('Hello Vy, you AI journey has begun')

# %%
print('Hello Vy, you AI journey has begun')

# %%
print('Hello Vy, you AI journey has begun')
# Out:
# Hello Vy, you AI journey has begun

# %%
import math
